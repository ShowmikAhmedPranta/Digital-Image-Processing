# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
img = cv2.imread('website.jpg')

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1020x510 at 0x7F12DC0E2C50>

# %%
import numpy as np

# %%
img1=img.reshape(-1)

# %%
img1
# Out:
# array([176, 182, 184, ..., 114, 118, 122], dtype=uint8)

# %%
plt.hist(img1)
# Out:
# (array([ 46812.,  31378.,  24992.,  28587.,  45135.,  30277.,  16097.,
#          43999.,  85085., 167838.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
img1.shape
# Out:
# (520200,)

# %%
img2=img1.tolist()

# %%
img2
# Out:
# [176,
#  182,
#  184,
#  173,
#  153,
#  144,
#  161,
#  184,
#  180,
#  181,
#  181,
#  181,
#  182,
#  182,
#  182,
#  183,
#  181,
#  185,
#  176,
#  182,
#  186,
#  131,
#  65,
#  50,
#  62,
#  75,
#  80,
#  84,
#  99,
#  111,
#  112,
#  110,
#  112,
#  119,
#  127,
#  129,
#  128,
#  129,
#  133,
#  137,
#  143,
#  145,
#  144,
#  144,
#  148,
#  144,
#  137,
#  136,
#  137,
#  134,
#  126,
#  119,
#  115,
#  115,
#  113,
#  109,
#  99,
#  96,
#  104,
#  78,
#  62,
#  55,
#  63,
#  68,
#  73,
#  73,
#  78,
#  85,
#  89,
#  90,
#  91,
#  92,
#  94,
#  96,
#  97,
#  98,
#  99,
#  100,
#  102,
#  103,
#  104,
#  103,
#  102,
#  102,
#  101,
#  99,
#  95,
#  92,
#  92,
#  85,
#  77,
#  73,
#  72,
#  71,
#  65,
#  61,
#  117,
#  184,
#  188,
#  193,
#  191,
#  189,
#  193,
#  190,
#  190,
#  191,
#  191,
#  191,
#  191,
#  191,
#  191,
#  191,
#  191,
#  191,
#  191,
#  191,
#  192,
#  192,
#  192,
#  192,
#  192,
#  192,
#  192,
#  192,
#  192,
#  192,
#  192,
#  192,
#  192,
# ...

# %%
len(img2)
# Out:
# 520200

# %%
img3=[]
for i in img2:
  if(i<125):
    img3.append(0)
  else:
    img3.append(255)

# %%
img.shape
# Out:
# (510, 1020)

# %%
img4=np.array(img3)

# %%
img5=img4.reshape(img.shape)

# %%
img5
# Out:
# array([[255, 255, 255, ...,   0, 255, 255],
#        [255, 255, 255, ...,   0,   0, 255],
#        [255, 255, 255, ...,   0,   0, 255],
#        ...,
#        [  0,   0,   0, ...,   0, 255, 255],
#        [  0,   0,   0, ...,   0,   0, 255],
#        [  0,   0,   0, ...,   0,   0,   0]])

# %%
cv2_imshow(img5)
# Out:
# <PIL.Image.Image image mode=L size=1020x510 at 0x7F12DA789DD0>

# %%
img6=img5.tolist()

# %%
even=[]
odd=[]

# %%
img5.shape
# Out:
# (510, 1020)

# %%
for i in range(2,500):
  if(i%2==0):
    even.append(sum(img6[i])/len(img6[i]))
  else:
    odd.append(sum(img6[i])/len(img6[i]))
if(len(odd)<len(even)):
  odd.append(sum(img6[500])/len(img6[500]))

if(len(odd)>len(even)):
  even.append(sum(img6[500])/len(img6[500]))

# %%
plt.scatter(even,odd)
